# %%
import pandas as pd

# %%
a = pd.read_excel('FREQUENCY_Insur_2.xlsx')
b = pd.read_excel('FREQUENCY_Insur_3.xlsx')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161742 entries, 0 to 161741
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   CERTIFICATE       161742 non-null  object
#  1   REG_NUMBER        161742 non-null  object
#  2   START_DATE        161742 non-null  datetime64[ns]
#  3   END_DATE          161742 non-null  datetime64[ns]
#  4   USE               161742 non-null  object
#  5   CAR_MAKER         161742 non-null  object
#  6   CAR_MODEL         161742 non-null  object
#  7   MANUFACTURE_YEAR  161742 non-null  int64
#  8   CAPACITY          161742 non-null  int64
#  9   NB_SEATS          161742 non-null  int64
#  10  SUM_INSURED       161742 non-null  int64
#  11  Year              161742 non-null  int64
#  12  Start_seq         161742 non-null  datetime64[ns]
#  13  End_seq           161742 non-null  datetime64[ns]
#  14  Days              161742 non-null  int64
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149246 entries, 0 to 149245
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   CERTIFICATE       149246 non-null  object
#  1   REG_NUMBER        149246 non-null  object
#  2   START_DATE        149246 non-null  datetime64[ns]
#  3   END_DATE          149246 non-null  datetime64[ns]
#  4   USE               149246 non-null  object
#  5   CAR_MAKER         149246 non-null  object
#  6   CAR_MODEL         149246 non-null  object
#  7   MANUFACTURE_YEAR  149246 non-null  int64
#  8   CAPACITY          149246 non-null  int64
#  9   NB_SEATS          149246 non-null  int64
#  10  SUM_INSURED       149246 non-null  int64
#  11  Year              149246 non-null  int64
#  12  Start_seq         149246 non-null  datetime64[ns]
#  13  End_seq           149246 non-null  datetime64[ns]
#  14  Days              149246 non-null  int64
# ...

# %%
b['MANUFACTURE_YEAR']=a['MANUFACTURE_YEAR'].astype('int64')
a['CAPACITY']=a['CAPACITY'].astype('int64')
a['SUM_INSURED']=a['SUM_INSURED'].astype('int64')

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149246 entries, 0 to 149245
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   CERTIFICATE       149246 non-null  object
#  1   REG_NUMBER        149246 non-null  object
#  2   START_DATE        149246 non-null  datetime64[ns]
#  3   END_DATE          149246 non-null  datetime64[ns]
#  4   USE               149246 non-null  object
#  5   CAR_MAKER         149246 non-null  object
#  6   CAR_MODEL         149246 non-null  object
#  7   MANUFACTURE_YEAR  149246 non-null  int64
#  8   CAPACITY          149246 non-null  int64
#  9   NB_SEATS          149246 non-null  int64
#  10  SUM_INSURED       149246 non-null  int64
#  11  Year              149246 non-null  int64
#  12  Start_seq         149246 non-null  datetime64[ns]
#  13  End_seq           149246 non-null  datetime64[ns]
#  14  Days              149246 non-null  int64
# ...

# %%
c = pd.concat([a,b])

# %%
c
# Out:
#          CERTIFICATE  REG_NUMBER START_DATE   END_DATE USE CAR_MAKER  \
# 0        + +13002366  29A-816.05 2014-01-14 2015-01-16   K     ACURA
# 1        + +14015473  69C-008.53 2014-04-06 2015-04-06   C   HYUNDAI
# 2        + +13017689   75C-02181 2014-01-20 2015-01-20   C       KIA
# 3        + +13017689   75C-02181 2014-01-20 2015-01-20   C       KIA
# 4        + +14027522   73A-02847 2014-04-21 2015-04-21   K    DAEWOO
# ...              ...         ...        ...        ...  ..       ...
# 149241      XH+99984    51F53007 2016-11-25 2017-11-25   C   HYUNDAI
# 149242      XH+99988   50LD03888 2016-11-25 2017-11-25   K      KH?C
# 149243      XH+99988   50LD03888 2016-11-25 2017-11-25   K      KH?C
# 149244    XH+XH89308  15R-116.23 2016-07-27 2017-07-27   C     ACURA
# 149245    XH+XH89308  15R-116.23 2016-07-27 2017-07-27   C     ACURA
#
#        CAR_MODEL  MANUFACTURE_YEAR  CAPACITY  NB_SEATS  SUM_INSURED  Year  \
# ...

# %%
c.to_excel('FREQUENCY_Insur_2+3.xlsx',index=False, engine='xlsxwriter')

# %%
c
# Out:
#          CERTIFICATE REG_NUMBER START_DATE   END_DATE USE CAR_MAKER CAR_MODEL  \
# 0           XH+12151  75A-01123 2016-06-26 2016-12-26   K    TOYOTA   4RUNNER
# 1         OT+0030814   53N-3564 2015-01-01 2015-12-31   K      KHAC      KHAC
# 2         OT+0030840   53N-4147 2015-01-01 2015-12-31   K      KHAC      KHAC
# 3      TN-BB+0142623    53N5395 2014-01-01 2014-12-31   K      KHAC      KHAC
# 4      TN-BB+0107053    53N3489 2014-01-01 2014-12-31   K      KHAC      KHAC
# ...              ...        ...        ...        ...  ..       ...       ...
# 39100   TN-BB+116223   49X-0070 2014-02-16 2017-02-16   K      KH�C      KH�C
# 39101   TN-BB+116223   49X-0070 2014-02-16 2017-02-16   K      KH�C      KH�C
# 39102   TN-BB+116223   49X-0070 2014-02-16 2017-02-16   K      KH�C      KH�C
# 39103   TN-BB+116223   49X-0070 2014-02-16 2017-02-16   K      KH�C      KH�C
# 39104     XH+0117795   34A16733 2016-10-19 2018-10-19   K      KHAC      KHAC
#
# ...
